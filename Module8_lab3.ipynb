# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhilvanama136/Fmml_module/blob/main/Module8_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-22 14:55:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   161MB/s    in 0.4s
#
# 2025-04-22 14:55:54 (161 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24085  1612.05062v2  Separating an image into reflectance and shadi...    cs
# 20434  1601.06108v1  Use of intelligent decision aids can help alle...    cs
# 11658  1609.00921v1  A universal unanswered question in neuroscienc...  stat
# 24751   1411.4670v1  In this paper, we introduce the first phase of...    cs
# 1767   1602.02850v1  Automated feature selection is important for t...  stat
# ...             ...                                                ...   ...
# 14317  1803.07554v1  In this paper, we introduce a powerful techniq...  stat
# 9395   1611.02304v2  We consider the problem of density estimation ...  stat
# 6728   1705.08665v4  Compression and computational efficiency in de...  stat
# 8329   1511.06049v2  Self-paced learning (SPL) is a recently raised...    cs
# 13124  1610.06656v2  In this paper we present a new algorithm for c...  stat
#
#                                                    title  year  \
# 24085  Reflectance Adaptive Filtering Improves Intrin...  2016
# 20434  Decision Aids for Adversarial Planning in Mili...  2016
# 11658  Decoding visual stimuli in human brain by usin...  2016
# 24751  AlexU-Word: A New Dataset for Isolated-Word Cl...  2014
# 1767   Toward Optimal Feature Selection in Naive Baye...  2016
# ...                                                  ...   ...
# 14317  The Leave-one-out Approach for Matrix Completi...  2018
# 9395           Normalizing Flows on Riemannian Manifolds  2016
# 6728              Bayesian Compression for Deep Learning  2017
# 8329   What Objective Does Self-paced Learning Indeed...  2015
# 13124                 Single Pass PCA of Matrix Products  2016
#
#                                                 keywords
# 24085  [separating, reflectance, challenge, approache...
# 20434  [intelligent, alleviate, challenges, operation...
# 11658  [universal, unanswered, neuroscience, computer...
# 24751  [introduce, handwriting, recognition, segmente...
# 1767   [automated, selection, important, categorizati...
# ...                                                  ...
# 14317  [introduce, technique, completion, technique, ...
# 9395   [estimation, riemannian, manifolds, estimation...
# 6728   [compression, computational, efficiency, signi...
# 8329   [methodology, simulating, principle, humansani...
# 13124  [algorithm, computing, approximation, straight...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 24085    [separating, reflectance, challenge, approache...
# 20434    [intelligent, alleviate, challenges, operation...
# 11658    [universal, unanswered, neuroscience, computer...
# 24751    [introduce, handwriting, recognition, segmente...
# 1767     [automated, selection, important, categorizati...
#                                ...
# 6834     [technique, canonical, correlation, comparing,...
# 6951     [annotated, sentiment, researchers, therefore,...
# 32143    [privileged, information, classifier, addition...
# 38537    [processing, processing, synthesis, polyphase,...
# 38649    [algorithm, geometrical, retrieval, geometrica...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8797 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e230b768-556e-4407-a7fe-6297319137dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e230b768-556e-4407-a7fe-6297319137dd")) {                    Plotly.newPlot(                        "e230b768-556e-4407-a7fe-6297319137dd",                        [{"x":["algorithm","approaches","processing","estimation","performance","filtering","implements","reflectance","estimated","sufficient","benchmark","intrinsic","technique","statistical","predictions","important","knowledge","achieving","judgments","constancy","operation","challenge","separating","decompositions","realistic","bilateral","competitive","dependencies","computational","reminiscent","adversary","constrained","experimental","technology","evaluation","challenges","originally","interleaving","intelligent","automatically","situations","translating","estimates","operations","consumption","actionable","scheduling","adversarial","tradeoffs","developed","particularly","alleviate","algorithms","engineering","favorably","requiring","validation","attrition","integrated","producing","imbalance","framework","unanswered","extraction","decreasing","addressing","homogeneous","consonants","anatomical","mentioned","correcting","computers","prediction","neuroscience","overcoming","demonstrate","extracted","universal","increasing","categories","classification","introduce","segmented","descriptor","handwriting","vocabulary","collected","descriptors","evaluated","classifiers","recognition","discriminative","automated","discrimination","efficient","classifier","divergence","hypothesis","promising","distribution","effectiveness","experiments","extensive","categorization","asymptotic","properties","information","selection","appearance","generally","segmentation","maximization","acceleration","multidimensional","supervised","accelerometers","regression","available","automatic","recognize","expectation","efficiency","sequential","accurately","expensive","consuming","therefore","unsupervised","difficult","activities","variational","smoothing","techniques","simulated","principal","decomposition","numerical","theoretical","component","optimization","formulations","representation","facilitates","applications","effectively","compression","reconstruction","preserves","standards","especially","outperforms","collaborate","reconstruct","understanding","denoising","compatible","frameworks","simultaneously","convolutional","structural","seamlessly","conditional","parametric","dependence","recommender","modelling","continuous","incomplete","variables","bivariate","approximation","inference","predictive","approximate","parameter","providing","movielens","corresponding","predicted","morgenstern","posterior","streaming","incremental","distributed","detection","furthermore","interface","scalability","satisfaction","including","combining","extensible","surveillance","requirement","heuristics","substitute","searching","relations","ambiguous","replacements"],"y":[798,428,273,198,927,67,15,5,56,60,202,45,239,179,85,379,320,67,12,3,41,154,6,9,56,10,117,63,267,2,12,56,393,55,264,127,17,2,55,204,45,17,63,76,22,5,25,109,11,211,87,29,604,53,20,50,57,2,55,29,11,583,0,119,10,26,16,1,7,17,8,13,232,8,5,535,119,33,112,61,502,311,22,24,7,38,65,42,129,95,357,98,98,18,401,125,27,59,94,197,204,618,180,30,19,213,651,163,57,93,182,38,21,11,199,1,147,311,193,50,32,151,82,75,76,34,133,136,149,35,51,25,360,60,27,59,78,160,95,319,17,340,16,436,118,46,86,24,7,114,243,5,38,175,44,13,33,133,385,77,8,94,43,15,21,58,128,34,133,1,116,207,57,116,125,86,2,139,33,0,37,16,33,100,334,162,31,30,17,280,101,5,25,39,44,4,30,100,19,2],"type":"bar"},{"x":["algorithm","approaches","processing","estimation","performance","filtering","implements","r ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Left</span> <span style=''>Center</span> <span style=''>Right</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separated</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>for</span> <span style=''>Aspect</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.5925925925925927);'>Sentiment</span> <span style=''>Analysis</span> <span style=''>with</span> <span style=''>Rotatory</span> <span style='background-color:rgba(0, 255, 0, 0.4360902255639098);'>Attention</span> <br/><br/><span style=''>Deep</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>have</span> <span style=''>achieved</span> <span style=''>success</span> <span style=''>in</span> <span style=''>aspect</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.5925925925925927);'>sentiment</span> <span style=''>analysis</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>However</span> <span style=''>there</span> <span style=''>are</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>issues</span> <span style=''>that</span> <span style=''>still</span> <span style=''>remain</span> <span style=''>to</span> <span style=''>be</span> <span style=''>further</span> <span style=''>studied</span> <span style=''>ie</span> <span style=''>1)</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.35897435897435903);'>represent</span> <span style=''>the</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>when</span> <span style=''>the</span> <span style=''>target</span> <span style=''>contains</span> <span style=''>multiple</span> <span style=''>words</span> <span style=''>2)</span> <span style=''>how</span> <span style=''>to</span> <span style=''>utilize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.45323741007194235);'>interaction</span> <span style=''>between</span> <span style=''>target</span> <span style=''>and</span> <span style=''>leftright</span> <span style=''>contexts</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>words</span> <span style=''>in</span> <span style=''>them</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>called</span> <span style=''>left</span> <span style=''>center</span> <span style=''>right</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separated</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>with</span> <span style=''>rotatory</span> <span style='background-color:rgba(0, 255, 0, 0.4360902255639098);'>attention</span> <span style=''>(LCR</span> <span style=''>Rot)</span> <span style=''>to</span> <span style=''>better</span> <span style=''>address</span> <span style=''>the</span> <span style=''>two</span> <span style=''>problems</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.41258741258741255);'>characteristics</span> <span style=''>1)</span> <span style=''>it</span> <span style=''>has</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separated</span> <span style=''>LSTMs</span> <span style=''>ie</span> <span style=''>left</span> <span style=''>center</span> <span style=''>and</span> <span style=''>right</span> <span style=''>LS ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>sparsity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interested</span> <span style=''>in</span> <span style=''>the</span> <span style=''>problems</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>when</span> <span style=''>the</span> <span style=''>input</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>described</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>a</span> <span style=''>few</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Our</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>model</span> <span style=''>hence</span> <span style=''>avoiding</span> <span style=''>linear</span> <span style=''>or</span> <span style=''>additive</span> <span style=''>models</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>each</span> <span style=''>variable</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style=''>by</span> <span style=''>making</span> <span style=''>use</span> <span style=''>of</span> <span style=''>partial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivatives</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuition</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>scheme</span> <span style=''>Using</span> <span style=''>concepts</span> <span style=''>and</span> <span style=''>results</span> <span style=''>from</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>spaces</span> <span style=''>and</span> <span style=''>proximal</span> <span style=''>methods</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>a ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Regularized</span> <span style=''>Trees</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>many</span> <span style=''>tree</span> <span style=''>models</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>to</span> <span style=''>penalize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>new</span> <span style=''>feature</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>splitting</span> <span style=''>when</span> <span style=''>its</span> <span style=''>gain</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>gain)</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>the</span> <span style=''>features</span> <span style=''>used</span> <span style=''>in</span> <span style=''>previous</span> <span style=''>splits</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>on</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>and</span> <span style=''>boosted</span> <span style=''>trees</span> <span style=''>here</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>other</span> <span style=''>tree</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3886925795053004);'>Experimental</span> <span style=''>studies</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>regularized</span> <span style=''>trees</span> <span style=''>can</span> <span style=''>select</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>feature</span> <span style=''>subsets</span> <span style=''>with</span> <span style=''>regard</span> <span style=''>to</span> <span style=''>both</span> <span style=''>strong</span> <span style=''>and</span> <span style=''>weak</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>Because</span> <span style=''>tree</span> <span style=''>models</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>deal</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categorical</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.4368231046931408);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3496332518337408);'>variables</span> <span style=''>missing</span> <span style=''>values</span> <span style='background-color:rgba(0, 255, 0, 0.3234782608695652);'>different</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Dynamics</span> <span style=''>Based</span> <span style=''>Features</span> <span style=''>For</span> <span style=''>Graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style=''>Numerous</span> <span style=''>social</span> <span style=''>medical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>can</span> <span style=''>be</span> <span style=''>framed</span> <span style=''>as</span> <span style=''>graph</span> <span style=''>based</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>feature</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>dynamics</span> <span style=''>on</span> <span style=''>a</span> <span style=''>network</span> <span style=''>can</span> <span style=''>be</span> <span style=''>useful</span> <span style=''>to</span> <span style=''>reveal</span> <span style=''>patterns</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>organization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style=''>where</span> <span style=''>the</span> <span style=''>process</span> <span style=''>takes</span> <span style=''>place</span> <span style=''>We</span> <span style=''>define</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>assortativities</span> <span style=''>on</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>use</span> <span style=''>them</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>features</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>time</span> <span style=''>scales</span> <span style=''>These</span> <span style=''>features</span> <span style=''>turn</span> <span style=''>out</span> <span style=''>to</span> <span style=''>be</span> <span style=''>suitable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>signatures</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminating</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>networks</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmarks</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>human</span> <span style=''>brain</span> <span style=''>networks</span> <span style=''>(connectomes)</span> <span style=''>and</span> <span style=''>use</span> <span style=''>it</span> <span style=''>to</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09405058781617386)
# 	challenging (0.10081938012112576)
# 	representation (0.12112575703598147)
# 	segmentation (0.06483790523690773)
# 	architecture (0.0883505521909512)
# 	experimental (0.14000712504453153)
# 	detection (0.11898824367652298)
# 	different (0.27110794442465264)
# 	recognition (0.12718204488778054)
# 	convolutional (0.1371571072319202)
#
# Some Statistics words are:
# 	theoretical (0.14751630707476165)
# 	stochastic (0.13748118414450577)
# 	variables (0.13848469643753136)
# 	estimation (0.16959357752132465)
# 	statistical (0.16507777220270947)
# 	algorithm (0.3878575012543904)
# 	distribution (0.17812343201204214)
# 	dimensional (0.18665328650275967)
# 	inference (0.19869543401906672)
# 	regression (0.1826392373306573)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c3da762-997c-409e-96ed-5f977cf5e12a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c3da762-997c-409e-96ed-5f977cf5e12a")) {                    Plotly.newPlot(                        "5c3da762-997c-409e-96ed-5f977cf5e12a",                        [{"x":["algorithm","approaches","processing","estimation","performance","filtering","implements","reflectance","estimated","sufficient","benchmark","intrinsic","technique","statistical","predictions","important","knowledge","achieving","judgments","constancy","operation","challenge","separating","decompositions","realistic","bilateral","competitive","dependencies","computational","reminiscent","adversary","constrained","experimental","technology","evaluation","challenges","originally","interleaving","intelligent","automatically","situations","translating","estimates","operations","consumption","actionable","scheduling","adversarial","tradeoffs","developed","particularly","alleviate","algorithms","engineering","favorably","requiring","validation","attrition","integrated","producing","imbalance","framework","unanswered","extraction","decreasing","addressing","homogeneous","consonants","anatomical","mentioned","correcting","computers","prediction","neuroscience","overcoming","demonstrate","extracted","universal","increasing","categories","classification","introduce","segmented","descriptor","handwriting","vocabulary","collected","descriptors","evaluated","classifiers","recognition","discriminative","automated","discrimination","efficient","classifier","divergence","hypothesis","promising","distribution","effectiveness","experiments","extensive","categorization","asymptotic","properties","information","selection","appearance","generally","segmentation","maximization","acceleration","multidimensional","supervised","accelerometers","regression","available","automatic","recognize","expectation","efficiency","sequential","accurately","expensive","consuming","therefore","unsupervised","difficult","activities","variational","smoothing","techniques","simulated","principal","decomposition","numerical","theoretical","component","optimization","formulations","representation","facilitates","applications","effectively","compression","reconstruction","preserves","standards","especially","outperforms","collaborate","reconstruct","understanding","denoising","compatible","frameworks","simultaneously","convolutional","structural","seamlessly","conditional","parametric","dependence","recommender","modelling","continuous","incomplete","variables","bivariate","approximation","inference","predictive","approximate","parameter","providing","movielens","corresponding","predicted","morgenstern","posterior","streaming","incremental","distributed","detection","furthermore","interface","scalability","satisfaction","including","combining","extensible","surveillance","requirement","heuristics","substitute","searching","relations","ambiguous","replacements","occurrences","proposing","traditional","documents","unannotated","relationship","disambiguation","approached","relatives","disambiguating","annotated","probability","measurements","relaxation","semidefinite","certificates","retrieval","equations","simulations","estimator","conditions","diffraction","inequality","geometric","representing","complexity","programming","associated","intersection","phaselift","symmetric","constraints","transition","quadratic","characterize","prohibitive","strategies","behaviour","emphmulti","formalise","simulation","availability","confidence","precisely","synthetic","obtainable","approximated","optimisation","scientific","empirically","approximations","eliminate","evaluations","augmentation","rotations","independent","challengi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unanswered
# 	morgenstern
# 	emphmulti
# 	inflation
# 	quantifiable
# 	marginalize
# 	substantiate
# 	practitioner
# 	textitnon
# 	faithfully
# 	methodologically
# 	returning
# 	magnetoencephalographic
# 	nonstationary
# 	inductively
# 	assortativity
# 	maneuvering
# 	roadworks
# 	curvatures
# 	individualized
# Some words which never appear in Statistics papers:
# 	constancy
# 	replacements
# 	unannotated
# 	disambiguating
# 	certificates
# 	equivariant
# 	subjectivity
# 	kinematic
# 	communicative
# 	projectors
# 	photometric
# 	proposition
# 	nonmonotonic
# 	deduction
# 	surrounded
# 	impression
# 	professionally
# 	watershed
# 	programmers
# 	recognise

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065040152025992e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
